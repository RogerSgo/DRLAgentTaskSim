# %%
import gymnasium 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import EnvCGR_T # entorno
import stable_baselines3
from stable_baselines3.common.env_checker import check_env # verificar el entorno

ENV_NAME = "EnvCGR_T/ConTask-v0"
env = gymnasium.make(ENV_NAME) 
#check_env(env, warn=True) # si funciona
# Out:
# Conectado al servidor API remoto

# %%
print("Espacio de observacion:", env.observation_space)
print("Shape Obs:", env.observation_space.shape) 
print("tipo de observacion:", env.observation_space.dtype) 
#print("Sample Obs:", env.observation_space.sample())
print("Espacio de accion:", env.action_space)
#print(env.get_imagen())
print("Action space sample:", env.action_space.sample())
#print("Estado:", env.vector_estado())
# Out:
# Espacio de observacion: Box(0, 255, (150, 50, 1), uint8)
# Shape Obs: (150, 50, 1)
# tipo de observacion: uint8
# Espacio de accion: Box(-1.0, 1.0, (3,), float32)
# Action space sample: [ 0.15553644  0.9828167  -0.20637111]

# %%
# Evaluar sistema con acciones aleatorias
acc=[]
X_ = []
Y_ = []
reward_points = 0#init_reward_points()

for episode in range(10):
    env.reset()
    #print(f'Episodio: {episode}')
    for step in range(10):
        env.render()
        env.step(env.action_space.sample())   # toma una accion aleatoria
        #time.sleep(5)
        reward = 0   #env.compute_reward(env.compute_distance(env.init_reward_points()))
        acc += [reward]
        X_.append(episode)
        Y_.append(np.array(acc).mean())
       
        print('Reecompensa Actual: {0:.3f}'.format(reward))
        #draw_rl_debug(env.step(env.action_space.sample()), reward_points)
    
plt.plot(X_, Y_)
plt.title('Recompensa medida')
plt.xlabel('Numero Episodios')
plt.ylabel('Recompensa')
plt.grid()
plt.show()
env.close()
# Out:
# --------------------------------------------------------------------
# STEP:  1
# Acciones:  [-0.90417     0.5081115   0.19289848]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.000
# RC: 0.250
# --- RECOMPENSA TOTAL: 0.250 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  2
# Acciones:  [-0.69004726  0.51954633  0.17302324]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.193
# RC: 0.250
# --- RECOMPENSA TOTAL: 0.250 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  3
# Acciones:  [ 0.02652659  0.02708912 -0.7784282 ]
# Angulos: Trayectoria Detectada: -0.060, Efector Final: 0.366
# RC: 0.250
# --- RECOMPENSA TOTAL: 0.250 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  4
# Acciones:  [-0.9898802   0.9904211  -0.87660104]
# Angulos: Trayectoria Detectada: -0.778, Efector Final: -0.413
# RC: 0.248
# --- RECOMPENSA TOTAL: 0.248 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  5
# Acciones:  [0.92773736 0.31389597 0.18473092]
# Angulos: Trayectoria Detectada: -0.290, Efector Final: -1.289
# RC: 0.248
# --- RECOMPENSA TOTAL: 0.248 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  6
# Acciones:  [-0.4145714   0.9071951   0.60199046]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -1.104
# RC: 0.248
# --- RECOMPENSA TOTAL: 0.248 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  7
# Acciones:  [ 0.9120085  -0.4508234  -0.02271899]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.502
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  8
# Acciones:  [-0.45244527 -0.56190205  0.5981051 ]
# Angulos: Trayectoria Detectada: 1.068, Efector Final: -0.525
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  9
# Acciones:  [ 0.32825822 -0.7728821   0.9658275 ]
# Angulos: Trayectoria Detectada: 2.273, Efector Final: 0.073
# RC: 0.247
# --- RECOMPENSA TOTAL: 0.247 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  10
# Acciones:  [0.11317463 0.17620933 0.42423052]
# Angulos: Trayectoria Detectada: 1.201, Efector Final: 1.039
# RC: 0.247
# --- RECOMPENSA TOTAL: 0.247 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  11
# Acciones:  [ 0.5814925  -0.4625983   0.01100731]
# Angulos: Trayectoria Detectada: -0.397, Efector Final: -0.000
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  12
# Acciones:  [-0.65190005  0.7795818   0.7483235 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.011
# RC: 0.250
# --- RECOMPENSA TOTAL: 0.250 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  13
# Acciones:  [ 0.06227322 -0.30313858 -0.22814766]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.759
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  14
# Acciones:  [-0.03437011  0.7160405  -0.15900414]
# Angulos: Trayectoria Detectada: 0.397, Efector Final: 0.531
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  15
# Acciones:  [ 0.552058    0.03587202 -0.73926985]
# Angulos: Trayectoria Detectada: -0.289, Efector Final: 0.372
# RC: 0.250
# --- RECOMPENSA TOTAL: 0.250 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  16
# Acciones:  [ 0.7890552  -0.7723018  -0.49558473]
# Angulos: Trayectoria Detectada: -4.696, Efector Final: -0.367
# RC: 0.243
# --- RECOMPENSA TOTAL: 0.243 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  17
# Acciones:  [0.21988362 0.71029735 0.7218326 ]
# Angulos: Trayectoria Detectada: -4.944, Efector Final: -0.863
# RC: 0.242
# --- RECOMPENSA TOTAL: 0.242 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  18
# Acciones:  [ 0.27192292 -0.33729908 -0.9922353 ]
# Angulos: Trayectoria Detectada: -7.404, Efector Final: -0.141
# RC: 0.240
# --- RECOMPENSA TOTAL: 0.240 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  19
# Acciones:  [-0.76350105  0.18833295 -0.93679374]
# Angulos: Trayectoria Detectada: -4.703, Efector Final: -1.133
# RC: 0.242
# --- RECOMPENSA TOTAL: 0.242 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  20
# Acciones:  [-0.01652164  0.8954511  -0.35611036]
# Angulos: Trayectoria Detectada: -3.874, Efector Final: -2.070
# RC: 0.242
# --- RECOMPENSA TOTAL: 0.242 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  21
# Acciones:  [-0.80740476  0.27106944 -0.22139151]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.000
# RC: 0.250
# --- RECOMPENSA TOTAL: 0.250 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  22
# Acciones:  [-0.66547316  0.3698832  -0.32159385]
# Angulos: Trayectoria Detectada: -0.686, Efector Final: -0.221
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  23
# Acciones:  [-0.894796   -0.29679617 -0.6973291 ]
# Angulos: Trayectoria Detectada: -0.824, Efector Final: -0.543
# RC: 0.248
# --- RECOMPENSA TOTAL: 0.248 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  24
# Acciones:  [-0.39462173  0.81069756 -0.4660411 ]
# Angulos: Trayectoria Detectada: -2.879, Efector Final: -1.240
# RC: 0.244
# --- RECOMPENSA TOTAL: 0.244 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  25
# Acciones:  [ 0.37810203 -0.3370393  -0.7748503 ]
# Angulos: Trayectoria Detectada: -3.462, Efector Final: -1.706
# RC: 0.243
# --- RECOMPENSA TOTAL: 0.243 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  26
# Acciones:  [ 0.9870526  -0.80322385 -0.53085166]
# Angulos: Trayectoria Detectada: -2.671, Efector Final: -2.481
# RC: 0.243
# --- RECOMPENSA TOTAL: 0.243 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  27
# Acciones:  [-0.798373  -0.7636878  0.510895 ]
# Angulos: Trayectoria Detectada: -2.097, Efector Final: -3.012
# RC: 0.243
# --- RECOMPENSA TOTAL: 0.243 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  28
# Acciones:  [ 0.17188998 -0.48090702 -0.10390814]
# Angulos: Trayectoria Detectada: -3.784, Efector Final: -2.501
# RC: 0.241
# --- RECOMPENSA TOTAL: 0.241 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  29
# Acciones:  [-0.8739061  -0.44564858  0.90662634]
# Angulos: Trayectoria Detectada: -1.344, Efector Final: -2.605
# RC: 0.245
# --- RECOMPENSA TOTAL: 0.245 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  30
# Acciones:  [ 0.8265337  -0.31977424 -0.47655976]
# Angulos: Trayectoria Detectada: -3.452, Efector Final: -1.698
# RC: 0.243
# --- RECOMPENSA TOTAL: 0.243 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  31
# Acciones:  [-0.04482996  0.45514295  0.8115103 ]
# Angulos: Trayectoria Detectada: 0.597, Efector Final: -0.000
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  32
# Acciones:  [ 0.12045696 -0.8767166   0.3142354 ]
# Angulos: Trayectoria Detectada: 1.813, Efector Final: 0.812
# RC: 0.246
# --- RECOMPENSA TOTAL: 0.246 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  33
# Acciones:  [-0.4186081  -0.12847538  0.87788177]
# Angulos: Trayectoria Detectada: 1.554, Efector Final: 1.126
# RC: 0.246
# --- RECOMPENSA TOTAL: 0.246 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  34
# Acciones:  [-0.95535374  0.7112235   0.25963283]
# Angulos: Trayectoria Detectada: 1.851, Efector Final: 2.004
# RC: 0.245
# --- RECOMPENSA TOTAL: 0.245 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  35
# Acciones:  [ 0.14360417  0.6638648  -0.9325503 ]
# Angulos: Trayectoria Detectada: 1.323, Efector Final: 2.263
# RC: 0.245
# --- RECOMPENSA TOTAL: 0.245 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  36
# Acciones:  [-0.19755109 -0.410969    0.07846935]
# Angulos: Trayectoria Detectada: 1.487, Efector Final: 1.331
# RC: 0.246
# --- RECOMPENSA TOTAL: 0.246 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  37
# Acciones:  [-0.5502168 -0.2950242  0.7413099]
# Angulos: Trayectoria Detectada: 1.632, Efector Final: 1.409
# RC: 0.246
# --- RECOMPENSA TOTAL: 0.246 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  38
# Acciones:  [ 0.68811625 -0.24400811  0.39564052]
# Angulos: Trayectoria Detectada: 3.742, Efector Final: 2.150
# RC: 0.242
# --- RECOMPENSA TOTAL: 0.242 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  39
# Acciones:  [-0.45003116 -0.60829574 -0.9479101 ]
# Angulos: Trayectoria Detectada: 0.939, Efector Final: 2.546
# RC: 0.245
# --- RECOMPENSA TOTAL: 0.245 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  40
# Acciones:  [-0.9078259  0.5406599 -0.8640864]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 1.598
# RC: 0.248
# --- RECOMPENSA TOTAL: 0.248 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  41
# Acciones:  [-0.46779713 -0.5256868  -0.13165143]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.000
# RC: 0.250
# --- RECOMPENSA TOTAL: 0.250 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  42
# Acciones:  [0.08719209 0.09520178 0.2191116 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.132
# RC: 0.250
# --- RECOMPENSA TOTAL: 0.250 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  43
# Acciones:  [ 0.7598328  -0.24801168  0.70958793]
# Angulos: Trayectoria Detectada: 1.012, Efector Final: 0.087
# RC: 0.248
# --- RECOMPENSA TOTAL: 0.248 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  44
# Acciones:  [-0.21807905 -0.7752588  -0.35950896]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.797
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  45
# Acciones:  [ 0.6731464  -0.11542331  0.09639356]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.438
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  46
# Acciones:  [-0.95391995  0.7667017  -0.03144422]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.534
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  47
# Acciones:  [0.87340117 0.95658946 0.63931525]
# Angulos: Trayectoria Detectada: -0.081, Efector Final: 0.502
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  48
# Acciones:  [ 0.79073906 -0.37960696  0.7337125 ]
# Angulos: Trayectoria Detectada: -0.856, Efector Final: 1.142
# RC: 0.250
# --- RECOMPENSA TOTAL: 0.250 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  49
# Acciones:  [-0.8330199  0.9376289 -0.9971166]
# Angulos: Trayectoria Detectada: 0.063, Efector Final: 1.876
# RC: 0.247
# --- RECOMPENSA TOTAL: 0.247 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  50
# Acciones:  [0.14575793 0.87079346 0.029327  ]
# Angulos: Trayectoria Detectada: -0.686, Efector Final: 0.878
# RC: 0.250
# --- RECOMPENSA TOTAL: 0.250 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  51
# Acciones:  [ 0.21248831 -0.34763718  0.12483373]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.000
# RC: 0.250
# --- RECOMPENSA TOTAL: 0.250 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  52
# Acciones:  [ 0.65969723 -0.79935694 -0.78512466]
# Angulos: Trayectoria Detectada: -2.898, Efector Final: 0.125
# RC: 0.246
# --- RECOMPENSA TOTAL: 0.246 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  53
# Acciones:  [-0.8865926  -0.3040765   0.28056756]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.660
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  54
# Acciones:  [ 0.29523113 -0.9171344  -0.58157885]
# Angulos: Trayectoria Detectada: -1.921, Efector Final: -0.380
# RC: 0.247
# --- RECOMPENSA TOTAL: 0.247 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  55
# Acciones:  [ 0.63080275 -0.7499476   0.6282616 ]
# Angulos: Trayectoria Detectada: -1.244, Efector Final: -0.961
# RC: 0.247
# --- RECOMPENSA TOTAL: 0.247 ---
#  --- REINICIO ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  56
# Acciones:  [-0.79613     0.48502523  0.96232975]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.333
# RC: 0.250
# --- RECOMPENSA TOTAL: 0.250 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  57
# Acciones:  [ 0.5053019  -0.44788632  0.6450826 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.629
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
#  --- REINICIO ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  58
# Acciones:  [-0.23909348  0.02296786 -0.44867253]
# Angulos: Trayectoria Detectada: 0.060, Efector Final: 1.274
# RC: 0.248
# --- RECOMPENSA TOTAL: 0.248 ---
#  --- REINICIO ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  59
# Acciones:  [-0.08639895  0.18995109  0.5428336 ]
# Angulos: Trayectoria Detectada: 0.597, Efector Final: 0.826
# RC: 0.248
# --- RECOMPENSA TOTAL: 0.248 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  60
# Acciones:  [-0.31897053  0.2783445  -0.04472752]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 1.369
# RC: 0.248
# --- RECOMPENSA TOTAL: 0.248 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  61
# Acciones:  [ 0.08973751 -0.26974523  0.48629528]
# Angulos: Trayectoria Detectada: 1.400, Efector Final: -0.000
# RC: 0.248
# --- RECOMPENSA TOTAL: 0.248 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  62
# Acciones:  [-0.55249274  0.6190202   0.8716147 ]
# Angulos: Trayectoria Detectada: 2.856, Efector Final: 0.486
# RC: 0.245
# --- RECOMPENSA TOTAL: 0.245 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  63
# Acciones:  [-0.70380837  0.37411943  0.3286042 ]
# Angulos: Trayectoria Detectada: 1.469, Efector Final: 1.358
# RC: 0.246
# --- RECOMPENSA TOTAL: 0.246 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  64
# Acciones:  [ 0.85730755 -0.90346384  0.75448346]
# Angulos: Trayectoria Detectada: 1.892, Efector Final: 1.687
# RC: 0.245
# --- RECOMPENSA TOTAL: 0.245 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  65
# Acciones:  [-0.5046822   0.7182688   0.04455629]
# Angulos: Trayectoria Detectada: 2.020, Efector Final: 2.441
# RC: 0.244
# --- RECOMPENSA TOTAL: 0.244 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  66
# Acciones:  [0.0529764  0.57992876 0.7649817 ]
# Angulos: Trayectoria Detectada: 3.317, Efector Final: 2.486
# RC: 0.242
# --- RECOMPENSA TOTAL: 0.242 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  67
# Acciones:  [-0.31888914 -0.67397696  0.15220088]
# Angulos: Trayectoria Detectada: 2.929, Efector Final: 3.251
# RC: 0.241
# --- RECOMPENSA TOTAL: 0.241 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  68
# Acciones:  [ 0.66483164 -0.9691521  -0.83752656]
# Angulos: Trayectoria Detectada: 3.864, Efector Final: 3.403
# RC: 0.240
# --- RECOMPENSA TOTAL: 0.240 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  69
# Acciones:  [-0.34304705 -0.9942416  -0.24592662]
# Angulos: Trayectoria Detectada: 1.536, Efector Final: 2.565
# RC: 0.244
# --- RECOMPENSA TOTAL: 0.244 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  70
# Acciones:  [0.7247881  0.5983929  0.33814198]
# Angulos: Trayectoria Detectada: 3.025, Efector Final: 2.319
# RC: 0.243
# --- RECOMPENSA TOTAL: 0.243 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  71
# Acciones:  [ 0.10177628 -0.8222324  -0.13846657]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.000
# RC: 0.250
# --- RECOMPENSA TOTAL: 0.250 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  72
# Acciones:  [ 0.7435681   0.77140605 -0.7271792 ]
# Angulos: Trayectoria Detectada: -0.856, Efector Final: -0.138
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  73
# Acciones:  [ 0.9861802  -0.05672167 -0.00812082]
# Angulos: Trayectoria Detectada: -6.694, Efector Final: -0.866
# RC: 0.240
# --- RECOMPENSA TOTAL: 0.240 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  74
# Acciones:  [-0.95075256  0.54207563  0.9758558 ]
# Angulos: Trayectoria Detectada: -0.178, Efector Final: -0.874
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  75
# Acciones:  [ 0.62360793 -0.9424171   0.26486975]
# Angulos: Trayectoria Detectada: -4.045, Efector Final: 0.102
# RC: 0.245
# --- RECOMPENSA TOTAL: 0.245 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  76
# Acciones:  [ 0.52225584 -0.04520344  0.15908328]
# Angulos: Trayectoria Detectada: -6.468, Efector Final: 0.367
# RC: 0.242
# --- RECOMPENSA TOTAL: 0.242 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  77
# Acciones:  [-0.401422   0.7436957  0.9275214]
# Angulos: Trayectoria Detectada: -4.281, Efector Final: 0.526
# RC: 0.245
# --- RECOMPENSA TOTAL: 0.245 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  78
# Acciones:  [ 0.02675905 -0.6673564   0.61823314]
# Angulos: Trayectoria Detectada: -2.664, Efector Final: 1.454
# RC: 0.248
# --- RECOMPENSA TOTAL: 0.248 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  79
# Acciones:  [0.81565326 0.25669438 0.40426648]
# Angulos: Trayectoria Detectada: -6.513, Efector Final: 2.072
# RC: 0.244
# --- RECOMPENSA TOTAL: 0.244 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  80
# Acciones:  [ 0.1627466   0.97492343 -0.04372838]
# Angulos: Trayectoria Detectada: -8.757, Efector Final: 2.476
# RC: 0.241
# --- RECOMPENSA TOTAL: 0.241 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  81
# Acciones:  [-0.2545783 -0.6840454 -0.8680127]
# Angulos: Trayectoria Detectada: -1.143, Efector Final: -0.000
# RC: 0.248
# --- RECOMPENSA TOTAL: 0.248 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  82
# Acciones:  [ 0.9946676  -0.1292662  -0.01144444]
# Angulos: Trayectoria Detectada: -3.613, Efector Final: -0.868
# RC: 0.244
# --- RECOMPENSA TOTAL: 0.244 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  83
# Acciones:  [ 0.31236467 -0.14151385  0.6422912 ]
# Angulos: Trayectoria Detectada: -2.329, Efector Final: -0.879
# RC: 0.246
# --- RECOMPENSA TOTAL: 0.246 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  84
# Acciones:  [ 0.11962827 -0.99516565  0.8286987 ]
# Angulos: Trayectoria Detectada: -1.780, Efector Final: -0.237
# RC: 0.247
# --- RECOMPENSA TOTAL: 0.247 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  85
# Acciones:  [ 0.51604986  0.6397047  -0.52718794]
# Angulos: Trayectoria Detectada: -4.792, Efector Final: 0.592
# RC: 0.244
# --- RECOMPENSA TOTAL: 0.244 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  86
# Acciones:  [-0.97212535  0.87757707  0.503185  ]
# Angulos: Trayectoria Detectada: -0.570, Efector Final: 0.064
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  87
# Acciones:  [ 0.0909156  0.7622682 -0.7461641]
# Angulos: Trayectoria Detectada: -1.239, Efector Final: 0.568
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  88
# Acciones:  [-0.99043304 -0.49044195 -0.86226225]
# Angulos: Trayectoria Detectada: -0.573, Efector Final: -0.179
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  89
# Acciones:  [ 0.571089   -0.08040863 -0.05159728]
# Angulos: Trayectoria Detectada: -3.149, Efector Final: -1.041
# RC: 0.244
# --- RECOMPENSA TOTAL: 0.244 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  90
# Acciones:  [-0.07620101  0.8700996  -0.620338  ]
# Angulos: Trayectoria Detectada: -1.817, Efector Final: -1.092
# RC: 0.246
# --- RECOMPENSA TOTAL: 0.246 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  91
# Acciones:  [0.37471426 0.5563792  0.48400578]
# Angulos: Trayectoria Detectada: 0.441, Efector Final: -0.000
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  92
# Acciones:  [ 0.47463053 -0.6322196   0.73426116]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.484
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  93
# Acciones:  [-0.42676634 -0.23282668 -0.7296353 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 1.218
# RC: 0.248
# --- RECOMPENSA TOTAL: 0.248 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  94
# Acciones:  [-0.28289914 -0.49401224 -0.9882212 ]
# Angulos: Trayectoria Detectada: -0.289, Efector Final: 0.489
# RC: 0.250
# --- RECOMPENSA TOTAL: 0.250 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  95
# Acciones:  [ 0.16937758  0.62837374 -0.92738163]
# Angulos: Trayectoria Detectada: -1.362, Efector Final: -0.500
# RC: 0.247
# --- RECOMPENSA TOTAL: 0.247 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  96
# Acciones:  [-0.8629954  -0.73571914  0.780436  ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -1.427
# RC: 0.248
# --- RECOMPENSA TOTAL: 0.248 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  97
# Acciones:  [-0.51683795 -0.67736727  0.9568828 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.647
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  98
# Acciones:  [-0.94629675  0.01970765 -0.47129834]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.310
# RC: 0.250
# --- RECOMPENSA TOTAL: 0.250 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  99
# Acciones:  [ 0.32353014 -0.29932988  0.59929603]
# Angulos: Trayectoria Detectada: 1.068, Efector Final: -0.161
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  100
# Acciones:  [ 0.855666   -0.71711105 -0.6904094 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.438
# RC: 0.249
# --- RECOMPENSA TOTAL: 0.249 ---
# Reecompensa Actual: 0.000
