# %%
import gymnasium 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import EnvCGR_T # entorno
import stable_baselines3
from stable_baselines3.common.env_checker import check_env # verificar el entorno

ENV_NAME = "EnvCGR_T/ConTask-v0"
env = gymnasium.make(ENV_NAME) 
#check_env(env, warn=True) # si funciona
# Out:
# Conectado al servidor API remoto

# %%
print("Espacio de observacion:", env.observation_space)
print("Shape Obs:", env.observation_space.shape) 
print("tipo de observacion:", env.observation_space.dtype) 
#print("Sample Obs:", env.observation_space.sample())
print("Espacio de accion:", env.action_space)
#print(env.get_imagen())
print("Action space sample:", env.action_space.sample())
#print("Estado:", env.vector_estado())
# Out:
# Espacio de observacion: Box(0, 255, (150, 50, 1), uint8)
# Shape Obs: (150, 50, 1)
# tipo de observacion: uint8
# Espacio de accion: Box(-1.0, 1.0, (3,), float32)
# Action space sample: [0.53727347 0.32976592 0.8600864 ]

# %%
# Evaluar sistema con acciones aleatorias
acc=[]
X_ = []
Y_ = []
reward_points = 0#init_reward_points()

for episode in range(10):
    env.reset()
    #print(f'Episodio: {episode}')
    for step in range(10):
        env.render()
        env.step(env.action_space.sample())   # toma una accion aleatoria
        #time.sleep(5)
        reward = 0   #env.compute_reward(env.compute_distance(env.init_reward_points()))
        acc += [reward]
        X_.append(episode)
        Y_.append(np.array(acc).mean())
       
        print('Reecompensa Actual: {0:.3f}'.format(reward))
        #draw_rl_debug(env.step(env.action_space.sample()), reward_points)
    
plt.plot(X_, Y_)
plt.title('Recompensa medida')
plt.xlabel('Numero Episodios')
plt.ylabel('Recompensa')
plt.grid()
plt.show()
env.close()
# Out:
# --------------------------------------------------------------------
# STEP:  1
# Acciones:  [-0.6047637   0.07879637 -0.90429914]
# Angulos: Trayectoria Detectada: -1.342, Efector Final: -0.000
# RT: 0.914, RC: 0.248, RG: -1.809, RA: 0.358, RF: 0.000
# --- RECOMPENSA TOTAL: -0.289 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  2
# Acciones:  [-0.18053316 -0.02013389  0.6207899 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.904
# RT: 0.914, RC: 0.249, RG: 1.242, RA: 0.105, RF: 0.000
# --- RECOMPENSA TOTAL: 2.509 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  3
# Acciones:  [-0.13652392 -0.68685657 -0.4456622 ]
# Angulos: Trayectoria Detectada: -1.320, Efector Final: -0.284
# RT: 0.619, RC: 0.248, RG: -0.891, RA: 0.317, RF: 0.000
# --- RECOMPENSA TOTAL: 0.292 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  4
# Acciones:  [-0.7569076   0.09677496 -0.46765056]
# Angulos: Trayectoria Detectada: -0.778, Efector Final: -0.729
# RT: 0.657, RC: 0.248, RG: -0.935, RA: 0.282, RF: 0.000
# --- RECOMPENSA TOTAL: 0.252 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  5
# Acciones:  [-0.32908612 -0.28907153 -0.7404074 ]
# Angulos: Trayectoria Detectada: -1.495, Efector Final: -1.197
# RT: 0.533, RC: 0.246, RG: -1.481, RA: 0.340, RF: 0.000
# --- RECOMPENSA TOTAL: -0.362 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  6
# Acciones:  [ 0.15923063  0.57528335 -0.6101486 ]
# Angulos: Trayectoria Detectada: -2.048, Efector Final: -1.937
# RT: 0.719, RC: 0.244, RG: -1.220, RA: 0.031, RF: 0.000
# --- RECOMPENSA TOTAL: -0.226 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  7
# Acciones:  [-0.06004044  0.13171868  0.96833915]
# Angulos: Trayectoria Detectada: -1.515, Efector Final: -2.547
# RT: 0.811, RC: 0.244, RG: 1.937, RA: 0.260, RF: 0.000
# --- RECOMPENSA TOTAL: 3.252 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  8
# Acciones:  [-0.6799781  -0.34626952  0.19311523]
# Angulos: Trayectoria Detectada: -1.291, Efector Final: -1.579
# RT: 0.657, RC: 0.246, RG: 0.386, RA: 0.208, RF: 0.000
# --- RECOMPENSA TOTAL: 1.498 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  9
# Acciones:  [ 0.99369395 -0.38358557  0.10358197]
# Angulos: Trayectoria Detectada: -1.329, Efector Final: -1.386
# RT: 0.549, RC: 0.246, RG: 0.207, RA: 0.178, RF: 0.000
# --- RECOMPENSA TOTAL: 1.181 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  10
# Acciones:  [0.73093754 0.07722863 0.7609748 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -1.282
# RT: 0.600, RC: 0.248, RG: -1.522, RA: 0.392, RF: 0.000
# --- RECOMPENSA TOTAL: -0.281 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  11
# Acciones:  [ 0.5031018  0.5505632 -0.8470514]
# Angulos: Trayectoria Detectada: -1.491, Efector Final: -0.000
# RT: 0.835, RC: 0.248, RG: -1.694, RA: 0.052, RF: 0.000
# --- RECOMPENSA TOTAL: -0.559 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  12
# Acciones:  [-0.11806651  0.5401165   0.3023619 ]
# Angulos: Trayectoria Detectada: -0.854, Efector Final: -0.847
# RT: 0.619, RC: 0.248, RG: 0.605, RA: 0.181, RF: 0.000
# --- RECOMPENSA TOTAL: 1.652 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  13
# Acciones:  [ 0.28621683  0.19247746 -0.44618458]
# Angulos: Trayectoria Detectada: -1.400, Efector Final: -0.545
# RT: 0.566, RC: 0.247, RG: -0.892, RA: 0.008, RF: 0.000
# --- RECOMPENSA TOTAL: -0.071 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  14
# Acciones:  [ 0.42922434 -0.3630957  -0.76451766]
# Angulos: Trayectoria Detectada: -4.327, Efector Final: -0.991
# RT: 0.719, RC: 0.243, RG: -1.529, RA: 0.175, RF: 0.000
# --- RECOMPENSA TOTAL: -0.393 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  15
# Acciones:  [ 0.4183109  -0.4272307  -0.26628563]
# Angulos: Trayectoria Detectada: -6.289, Efector Final: -1.755
# RT: 0.914, RC: 0.239, RG: -0.533, RA: 0.069, RF: 0.000
# --- RECOMPENSA TOTAL: 0.689 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  16
# Acciones:  [ 0.45193833 -0.75575995  0.70190907]
# Angulos: Trayectoria Detectada: -8.492, Efector Final: -2.022
# RT: 0.719, RC: 0.235, RG: 1.404, RA: 0.100, RF: 0.000
# --- RECOMPENSA TOTAL: 2.458 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  17
# Acciones:  [ 0.42250827 -0.8593085   0.49968567]
# Angulos: Trayectoria Detectada: -10.100, Efector Final: -1.320
# RT: 0.445, RC: 0.234, RG: 0.999, RA: 0.016, RF: 0.000
# --- RECOMPENSA TOTAL: 1.694 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  18
# Acciones:  [0.12405493 0.8616899  0.72525525]
# Angulos: Trayectoria Detectada: -10.519, Efector Final: -0.820
# RT: 0.741, RC: 0.234, RG: 1.451, RA: 0.428, RF: 0.000
# --- RECOMPENSA TOTAL: 2.853 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  19
# Acciones:  [-0.9534333 -0.935539   0.8901307]
# Angulos: Trayectoria Detectada: -2.664, Efector Final: -0.095
# RT: 0.487, RC: 0.246, RG: 1.780, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 2.763 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  20
# Acciones:  [ 0.04846269 -0.0888248   0.596298  ]
# Angulos: Trayectoria Detectada: -3.010, Efector Final: 0.795
# RT: 0.487, RC: 0.247, RG: 1.193, RA: 0.139, RF: 0.000
# --- RECOMPENSA TOTAL: 2.065 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  21
# Acciones:  [-0.16447146 -0.47566438  0.8084672 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.000
# RT: 0.741, RC: 0.250, RG: 1.617, RA: 0.042, RF: 0.000
# --- RECOMPENSA TOTAL: 2.650 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  22
# Acciones:  [-0.29028288 -0.8791732  -0.24612625]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.808
# RT: 0.458, RC: 0.249, RG: -0.492, RA: 0.354, RF: 0.000
# --- RECOMPENSA TOTAL: 0.569 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  23
# Acciones:  [ 0.05703805 -0.14227735 -0.04774656]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.562
# RT: 0.432, RC: 0.249, RG: 0.095, RA: 0.033, RF: 0.000
# --- RECOMPENSA TOTAL: 0.810 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  24
# Acciones:  [-0.65426487  0.4402627   0.10393292]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.515
# RT: 0.549, RC: 0.249, RG: -0.208, RA: 0.028, RF: 0.000
# --- RECOMPENSA TOTAL: 0.618 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  25
# Acciones:  [ 0.66999614 -0.24469739 -0.19000478]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.619
# RT: 0.472, RC: 0.249, RG: -0.380, RA: 0.059, RF: 0.000
# --- RECOMPENSA TOTAL: 0.400 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  26
# Acciones:  [-0.2411777 -0.1549514 -0.7528535]
# Angulos: Trayectoria Detectada: -1.483, Efector Final: 0.429
# RT: 0.419, RC: 0.249, RG: -1.506, RA: 0.287, RF: 0.000
# --- RECOMPENSA TOTAL: -0.551 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  27
# Acciones:  [0.084713   0.7700247  0.94367665]
# Angulos: Trayectoria Detectada: 1.400, Efector Final: -0.324
# RT: 0.657, RC: 0.249, RG: -1.887, RA: 0.450, RF: 0.000
# --- RECOMPENSA TOTAL: -0.532 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  28
# Acciones:  [ 0.37638816 -0.33150056 -0.99133193]
# Angulos: Trayectoria Detectada: -0.397, Efector Final: 0.619
# RT: 0.533, RC: 0.250, RG: -1.983, RA: 0.237, RF: 0.000
# --- RECOMPENSA TOTAL: -0.964 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  29
# Acciones:  [-0.72396076  0.21943776 -0.5862506 ]
# Angulos: Trayectoria Detectada: -0.772, Efector Final: -0.372
# RT: 0.583, RC: 0.248, RG: -1.173, RA: 0.273, RF: 0.000
# --- RECOMPENSA TOTAL: -0.069 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  30
# Acciones:  [-0.16389382  0.6494008   0.6386451 ]
# Angulos: Trayectoria Detectada: -1.379, Efector Final: -0.958
# RT: 0.861, RC: 0.247, RG: 1.277, RA: 0.281, RF: 0.000
# --- RECOMPENSA TOTAL: 2.666 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  31
# Acciones:  [0.55106187 0.41367927 0.3804745 ]
# Angulos: Trayectoria Detectada: 0.243, Efector Final: -0.000
# RT: 0.835, RC: 0.250, RG: -0.761, RA: 0.336, RF: 0.000
# --- RECOMPENSA TOTAL: 0.660 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  32
# Acciones:  [-0.628792   -0.8651872   0.33482406]
# Angulos: Trayectoria Detectada: 0.686, Efector Final: 0.380
# RT: 0.763, RC: 0.249, RG: -0.670, RA: 0.290, RF: 0.000
# --- RECOMPENSA TOTAL: 0.632 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  33
# Acciones:  [ 0.6872354  -0.29339138  0.05783162]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.715
# RT: 0.657, RC: 0.249, RG: -0.116, RA: 0.113, RF: 0.000
# --- RECOMPENSA TOTAL: 0.903 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  34
# Acciones:  [ 0.956762   -0.94234776  0.73055094]
# Angulos: Trayectoria Detectada: -1.949, Efector Final: 0.773
# RT: 0.395, RC: 0.248, RG: 1.461, RA: 0.186, RF: 0.000
# --- RECOMPENSA TOTAL: 2.290 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  35
# Acciones:  [-0.51041687 -0.3427986   0.4503994 ]
# Angulos: Trayectoria Detectada: 0.334, Efector Final: 1.504
# RT: 0.340, RC: 0.247, RG: -0.901, RA: 0.101, RF: 0.000
# --- RECOMPENSA TOTAL: -0.213 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  36
# Acciones:  [-0.2836124 -0.8724157  0.4019709]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 1.954
# RT: 0.217, RC: 0.247, RG: -0.804, RA: 0.189, RF: 0.000
# --- RECOMPENSA TOTAL: -0.152 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  37
# Acciones:  [0.4807211  0.63464016 0.09773292]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 2.356
# RT: 0.301, RC: 0.247, RG: 0.195, RA: 0.303, RF: 0.000
# --- RECOMPENSA TOTAL: 1.047 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  38
# Acciones:  [-0.07766175  0.9613439   0.37600005]
# Angulos: Trayectoria Detectada: 1.200, Efector Final: 2.454
# RT: 0.517, RC: 0.245, RG: -0.752, RA: 0.315, RF: 0.000
# --- RECOMPENSA TOTAL: 0.325 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  39
# Acciones:  [ 0.07676303 -0.8101517   0.02106258]
# Angulos: Trayectoria Detectada: 0.981, Efector Final: 2.830
# RT: 0.330, RC: 0.245, RG: -0.042, RA: 0.178, RF: 0.000
# --- RECOMPENSA TOTAL: 0.710 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  40
# Acciones:  [ 0.12063156 -0.5805596  -0.4026059 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 2.851
# RT: 0.237, RC: 0.246, RG: 0.805, RA: 0.216, RF: 0.000
# --- RECOMPENSA TOTAL: 1.504 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  41
# Acciones:  [-0.94898695 -0.38407668  0.6283736 ]
# Angulos: Trayectoria Detectada: 0.289, Efector Final: -0.000
# RT: 0.787, RC: 0.250, RG: -1.257, RA: 0.176, RF: 0.000
# --- RECOMPENSA TOTAL: -0.044 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  42
# Acciones:  [ 0.18282299 -0.327031   -0.10071664]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.628
# RT: 0.657, RC: 0.249, RG: 0.201, RA: 0.061, RF: 0.000
# --- RECOMPENSA TOTAL: 1.169 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  43
# Acciones:  [ 0.70915407  0.13232705 -0.76033634]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.528
# RT: 0.677, RC: 0.249, RG: 1.521, RA: 0.020, RF: 0.000
# --- RECOMPENSA TOTAL: 2.467 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  44
# Acciones:  [-0.12492489  0.68942     0.3669951 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.233
# RT: 1.000, RC: 0.250, RG: 0.734, RA: 0.233, RF: 0.000
# --- RECOMPENSA TOTAL: 2.217 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  45
# Acciones:  [-0.47034878 -0.2021031  -0.9955703 ]
# Angulos: Trayectoria Detectada: -1.520, Efector Final: 0.134
# RT: 0.861, RC: 0.248, RG: -1.991, RA: 0.417, RF: 0.000
# --- RECOMPENSA TOTAL: -0.465 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  46
# Acciones:  [ 0.89897007 -0.07372002  0.40536055]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.861
# RT: 0.835, RC: 0.249, RG: 0.811, RA: 0.308, RF: 0.000
# --- RECOMPENSA TOTAL: 2.202 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  47
# Acciones:  [-0.4064451  0.5576369 -0.4255322]
# Angulos: Trayectoria Detectada: -0.939, Efector Final: -0.456
# RT: 0.887, RC: 0.248, RG: -0.851, RA: 0.069, RF: 0.000
# --- RECOMPENSA TOTAL: 0.353 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  48
# Acciones:  [ 0.75731987 -0.2026296   0.93806386]
# Angulos: Trayectoria Detectada: -0.177, Efector Final: -0.881
# RT: 0.970, RC: 0.249, RG: 1.876, RA: 0.373, RF: 0.000
# --- RECOMPENSA TOTAL: 3.468 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  49
# Acciones:  [-0.81413996  0.6048371   0.35020497]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.057
# RT: 0.677, RC: 0.250, RG: 0.700, RA: 0.035, RF: 0.000
# --- RECOMPENSA TOTAL: 1.663 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  50
# Acciones:  [-0.39797536  0.75428087 -0.6827565 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.407
# RT: 0.458, RC: 0.249, RG: 1.366, RA: 0.082, RF: 0.000
# --- RECOMPENSA TOTAL: 2.155 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  51
# Acciones:  [ 0.25370222 -0.718607    0.4274616 ]
# Angulos: Trayectoria Detectada: 0.177, Efector Final: -0.000
# RT: 0.638, RC: 0.250, RG: -0.855, RA: 0.009, RF: 0.000
# --- RECOMPENSA TOTAL: 0.042 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  52
# Acciones:  [-0.5246998  -0.19170795  0.5258979 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.427
# RT: 0.600, RC: 0.249, RG: -1.052, RA: 0.048, RF: 0.000
# --- RECOMPENSA TOTAL: -0.154 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  53
# Acciones:  [ 0.74889916 -0.68920964  0.3070822 ]
# Angulos: Trayectoria Detectada: 0.456, Efector Final: 0.953
# RT: 0.407, RC: 0.248, RG: -0.614, RA: 0.092, RF: 0.000
# --- RECOMPENSA TOTAL: 0.132 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  54
# Acciones:  [ 0.03976822 -0.87052655  0.03027165]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 1.260
# RT: 0.252, RC: 0.248, RG: 0.061, RA: 0.200, RF: 0.000
# --- RECOMPENSA TOTAL: 0.760 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  55
# Acciones:  [-0.2485305  -0.33784673 -0.7537911 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 1.291
# RT: 0.204, RC: 0.248, RG: -1.508, RA: 0.335, RF: 0.000
# --- RECOMPENSA TOTAL: -0.720 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  56
# Acciones:  [-0.708028    0.16877885 -0.560084  ]
# Angulos: Trayectoria Detectada: -0.000, Efector Final: 0.537
# RT: 0.217, RC: 0.249, RG: -1.120, RA: 0.275, RF: 0.000
# --- RECOMPENSA TOTAL: -0.380 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  57
# Acciones:  [ 0.12441304 -0.46730664 -0.13342385]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.023
# RT: 0.170, RC: 0.250, RG: 0.267, RA: 0.119, RF: 0.000
# --- RECOMPENSA TOTAL: 0.806 ---
#  --- REINICIO ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  58
# Acciones:  [ 0.06101988 -0.9444376  -0.11543061]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.157
# RT: 0.130, RC: 0.250, RG: -0.231, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 0.399 ---
#  --- REINICIO ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  59
# Acciones:  [ 0.8530325   0.56190836 -0.02709741]
# Angulos: Trayectoria Detectada: -0.141, Efector Final: -0.272
# RT: 0.151, RC: 0.249, RG: -0.054, RA: 0.347, RF: 0.000
# --- RECOMPENSA TOTAL: 0.693 ---
#  --- REINICIO ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  60
# Acciones:  [-0.30752784  0.7157245   0.9012786 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.299
# RT: 0.204, RC: 0.250, RG: 1.803, RA: 0.327, RF: 0.000
# --- RECOMPENSA TOTAL: 2.583 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  61
# Acciones:  [ 0.82568467 -0.99516886  0.60509956]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.000
# RT: 0.549, RC: 0.250, RG: -1.210, RA: 0.109, RF: 0.000
# --- RECOMPENSA TOTAL: -0.302 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  62
# Acciones:  [ 0.5737618  -0.2744154  -0.73962706]
# Angulos: Trayectoria Detectada: -3.920, Efector Final: 0.605
# RT: 0.445, RC: 0.245, RG: -1.479, RA: 0.110, RF: 0.000
# --- RECOMPENSA TOTAL: -0.679 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  63
# Acciones:  [-0.08273169 -0.15337048 -0.7954991 ]
# Angulos: Trayectoria Detectada: -2.940, Efector Final: -0.135
# RT: 0.395, RC: 0.246, RG: -1.591, RA: 0.258, RF: 0.000
# --- RECOMPENSA TOTAL: -0.693 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  64
# Acciones:  [0.6524097  0.06229973 0.7289676 ]
# Angulos: Trayectoria Detectada: -7.268, Efector Final: -0.930
# RT: 0.407, RC: 0.239, RG: 1.458, RA: 0.361, RF: 0.000
# --- RECOMPENSA TOTAL: 2.464 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  65
# Acciones:  [-0.24671847 -0.49908426 -0.78484523]
# Angulos: Trayectoria Detectada: -6.737, Efector Final: -0.201
# RT: 0.310, RC: 0.240, RG: -1.570, RA: 0.383, RF: 0.000
# --- RECOMPENSA TOTAL: -0.636 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  66
# Acciones:  [-0.7831452  -0.25478423 -0.99600387]
# Angulos: Trayectoria Detectada: -3.255, Efector Final: -0.986
# RT: 0.259, RC: 0.244, RG: -1.992, RA: 0.508, RF: 0.000
# --- RECOMPENSA TOTAL: -0.980 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  67
# Acciones:  [0.8200173  0.31974852 0.33612892]
# Angulos: Trayectoria Detectada: -7.348, Efector Final: -1.982
# RT: 0.310, RC: 0.237, RG: 0.672, RA: 0.369, RF: 0.000
# --- RECOMPENSA TOTAL: 1.589 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  68
# Acciones:  [-0.28085604  0.5110719  -0.22023691]
# Angulos: Trayectoria Detectada: -7.037, Efector Final: -1.646
# RT: 0.407, RC: 0.238, RG: -0.440, RA: 0.002, RF: 0.000
# --- RECOMPENSA TOTAL: 0.207 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  69
# Acciones:  [-0.6004631  -0.06852262  0.44537857]
# Angulos: Trayectoria Detectada: -3.163, Efector Final: -1.866
# RT: 0.407, RC: 0.243, RG: 0.891, RA: 0.056, RF: 0.000
# --- RECOMPENSA TOTAL: 1.596 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  70
# Acciones:  [-0.97628164 -0.8786398  -0.91136783]
# Angulos: Trayectoria Detectada: -1.239, Efector Final: -1.421
# RT: 0.244, RC: 0.246, RG: -1.823, RA: 0.692, RF: 0.000
# --- RECOMPENSA TOTAL: -0.641 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  71
# Acciones:  [-0.3220639  0.6417676 -0.3566388]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.000
# RT: 0.763, RC: 0.250, RG: -0.713, RA: 0.009, RF: 0.000
# --- RECOMPENSA TOTAL: 0.309 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  72
# Acciones:  [-0.636865   -0.87090397  0.7354242 ]
# Angulos: Trayectoria Detectada: 2.517, Efector Final: -0.357
# RT: 0.811, RC: 0.247, RG: -1.471, RA: 0.193, RF: 0.000
# --- RECOMPENSA TOTAL: -0.220 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  73
# Acciones:  [-0.66685975 -0.07366595 -0.9018225 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 0.379
# RT: 0.763, RC: 0.249, RG: -1.804, RA: 0.411, RF: 0.000
# --- RECOMPENSA TOTAL: -0.380 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  74
# Acciones:  [ 0.79747087 -0.34173405 -0.7026544 ]
# Angulos: Trayectoria Detectada: -2.922, Efector Final: -0.523
# RT: 0.600, RC: 0.245, RG: -1.405, RA: 0.062, RF: 0.000
# --- RECOMPENSA TOTAL: -0.498 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  75
# Acciones:  [-0.5822245  0.3205192 -0.9984402]
# Angulos: Trayectoria Detectada: -4.415, Efector Final: -1.226
# RT: 0.698, RC: 0.242, RG: -1.997, RA: 0.315, RF: 0.000
# --- RECOMPENSA TOTAL: -0.742 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  76
# Acciones:  [-0.61762595  0.1035999  -0.21229078]
# Angulos: Trayectoria Detectada: -2.929, Efector Final: -2.224
# RT: 0.719, RC: 0.243, RG: -0.425, RA: 0.182, RF: 0.000
# --- RECOMPENSA TOTAL: 0.719 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  77
# Acciones:  [ 0.23298526  0.79571795 -0.6847127 ]
# Angulos: Trayectoria Detectada: -2.378, Efector Final: -2.436
# RT: 0.914, RC: 0.243, RG: -1.369, RA: 0.086, RF: 0.000
# --- RECOMPENSA TOTAL: -0.126 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  78
# Acciones:  [0.9122045  0.93151075 0.5898433 ]
# Angulos: Trayectoria Detectada: -4.343, Efector Final: -3.121
# RT: 0.533, RC: 0.240, RG: 1.180, RA: 0.608, RF: 0.000
# --- RECOMPENSA TOTAL: 2.560 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  79
# Acciones:  [-0.09368578 -0.94889444  0.45938548]
# Angulos: Trayectoria Detectada: -2.053, Efector Final: -2.531
# RT: 0.887, RC: 0.244, RG: 0.919, RA: 0.146, RF: 0.000
# --- RECOMPENSA TOTAL: 2.195 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  80
# Acciones:  [-0.12625958  0.2886185   0.18280464]
# Angulos: Trayectoria Detectada: -0.799, Efector Final: -2.072
# RT: 0.763, RC: 0.246, RG: 0.366, RA: 0.086, RF: 0.000
# --- RECOMPENSA TOTAL: 1.461 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  81
# Acciones:  [0.29315078 0.4261868  0.7049086 ]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: -0.000
# RT: 0.835, RC: 0.250, RG: 1.410, RA: 0.356, RF: 0.000
# --- RECOMPENSA TOTAL: 2.851 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  82
# Acciones:  [-0.9195815  -0.276158    0.97605383]
# Angulos: Trayectoria Detectada: 2.753, Efector Final: 0.705
# RT: 0.942, RC: 0.245, RG: -1.952, RA: 0.055, RF: 0.000
# --- RECOMPENSA TOTAL: -0.710 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  83
# Acciones:  [ 0.8776531   0.1904049  -0.20668718]
# Angulos: Trayectoria Detectada: 2.647, Efector Final: 1.681
# RT: 0.861, RC: 0.244, RG: 0.413, RA: 0.215, RF: 0.000
# --- RECOMPENSA TOTAL: 1.733 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  84
# Acciones:  [ 0.96264094 -0.8093189   0.9054156 ]
# Angulos: Trayectoria Detectada: -0.521, Efector Final: 1.474
# RT: 0.763, RC: 0.249, RG: 1.811, RA: 0.265, RF: 0.000
# --- RECOMPENSA TOTAL: 3.088 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  85
# Acciones:  [-0.7085168  -0.58532095  0.04096732]
# Angulos: Trayectoria Detectada: 3.440, Efector Final: 2.380
# RT: 0.566, RC: 0.242, RG: -0.082, RA: 0.313, RF: 0.000
# --- RECOMPENSA TOTAL: 1.039 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  86
# Acciones:  [ 0.08349948  0.31463826 -0.26575318]
# Angulos: Trayectoria Detectada: 3.012, Efector Final: 2.421
# RT: 0.657, RC: 0.242, RG: 0.532, RA: 0.033, RF: 0.000
# --- RECOMPENSA TOTAL: 1.464 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  87
# Acciones:  [-0.12751378 -0.34177312 -0.7200096 ]
# Angulos: Trayectoria Detectada: 0.146, Efector Final: 2.155
# RT: 0.533, RC: 0.247, RG: 1.440, RA: 0.297, RF: 0.000
# --- RECOMPENSA TOTAL: 2.517 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  88
# Acciones:  [-0.02762889 -0.78272885  0.6070458 ]
# Angulos: Trayectoria Detectada: 0.985, Efector Final: 1.435
# RT: 0.350, RC: 0.247, RG: -1.214, RA: 0.051, RF: 0.000
# --- RECOMPENSA TOTAL: -0.567 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  89
# Acciones:  [-0.7044251  -0.80558085  0.69648004]
# Angulos: Trayectoria Detectada: 1.761, Efector Final: 2.042
# RT: 0.237, RC: 0.245, RG: -1.393, RA: 0.203, RF: 0.000
# --- RECOMPENSA TOTAL: -0.708 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  90
# Acciones:  [ 0.86271536 -0.28649017 -0.6579274 ]
# Angulos: Trayectoria Detectada: 1.975, Efector Final: 2.738
# RT: 0.192, RC: 0.243, RG: 1.316, RA: 0.020, RF: 0.000
# --- RECOMPENSA TOTAL: 1.772 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  91
# Acciones:  [ 0.17498967 -0.78629875 -0.6510525 ]
# Angulos: Trayectoria Detectada: -0.063, Efector Final: -0.000
# RT: 0.566, RC: 0.250, RG: -1.302, RA: 0.316, RF: 0.000
# --- RECOMPENSA TOTAL: -0.171 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  92
# Acciones:  [ 0.960953   -0.6521985   0.46464342]
# Angulos: Trayectoria Detectada: -1.549, Efector Final: -0.651
# RT: 0.395, RC: 0.247, RG: 0.929, RA: 0.193, RF: 0.000
# --- RECOMPENSA TOTAL: 1.764 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  93
# Acciones:  [ 0.31942782 -0.5048034  -0.7431466 ]
# Angulos: Trayectoria Detectada: -5.064, Efector Final: -0.186
# RT: 0.292, RC: 0.243, RG: -1.486, RA: 0.232, RF: 0.000
# --- RECOMPENSA TOTAL: -0.719 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  94
# Acciones:  [-0.06972808  0.7655945   0.23109713]
# Angulos: Trayectoria Detectada: -4.378, Efector Final: -0.930
# RT: 0.445, RC: 0.243, RG: 0.462, RA: 0.232, RF: 0.000
# --- RECOMPENSA TOTAL: 1.381 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  95
# Acciones:  [0.28273037 0.14094847 0.25865015]
# Angulos: Trayectoria Detectada: -4.770, Efector Final: -0.698
# RT: 0.487, RC: 0.242, RG: 0.517, RA: 0.171, RF: 0.000
# --- RECOMPENSA TOTAL: 1.417 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  96
# Acciones:  [-0.62100524  0.829746   -0.2556183 ]
# Angulos: Trayectoria Detectada: -1.355, Efector Final: -0.440
# RT: 0.763, RC: 0.248, RG: -0.511, RA: 0.012, RF: 0.000
# --- RECOMPENSA TOTAL: 0.511 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  97
# Acciones:  [-0.15521581  0.3728791  -0.13290475]
# Angulos: Trayectoria Detectada: -2.783, Efector Final: -0.695
# RT: 0.942, RC: 0.245, RG: -0.266, RA: 0.021, RF: 0.000
# --- RECOMPENSA TOTAL: 0.942 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  98
# Acciones:  [-0.30369478  0.02592818  0.15755677]
# Angulos: Trayectoria Detectada: -1.760, Efector Final: -0.828
# RT: 0.970, RC: 0.246, RG: 0.315, RA: 0.030, RF: 0.000
# --- RECOMPENSA TOTAL: 1.562 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  99
# Acciones:  [0.27874884 0.81546706 0.3980956 ]
# Angulos: Trayectoria Detectada: -1.640, Efector Final: -0.671
# RT: 0.657, RC: 0.247, RG: 0.796, RA: 0.373, RF: 0.000
# --- RECOMPENSA TOTAL: 2.073 ---
# Reecompensa Actual: 0.000
# --------------------------------------------------------------------
# STEP:  100
# Acciones:  [-0.03132712 -0.2897005   0.8790984 ]
# Angulos: Trayectoria Detectada: -2.189, Efector Final: -0.273
# RT: 0.741, RC: 0.247, RG: 1.758, RA: 0.140, RF: 0.000
# --- RECOMPENSA TOTAL: 2.885 ---
# Reecompensa Actual: 0.000
