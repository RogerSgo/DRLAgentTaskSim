# %%
# Inferencia con ciclo anidado, for - while
import gymnasium   #
import EnvCGR_T   # Entorno personalizado
import stable_baselines3   # Biblioteca RL
from stable_baselines3 import A2C, PPO
from matplotlib import pyplot as plt 
import pandas as pd
import numpy as np

# Inicializar el entorno

ENV_NAME = "EnvCGR_T/ConTask-v0"
#ENV_NAME = "CoppeliaSim_Gym/GymCoppManR-v0"
env = gymnasium.make(ENV_NAME)
model = A2C.load("best_model", env=env)
val = []
X_ = []
Y_ = []
vx = []
vy = []
all_episode_rewards = []
num_episodes = 1
for i in range(num_episodes):
    episode_rewards = []
    done = False
    obs, info = env.reset()
    while not done:
        env.render()
        # states solo son útiles cuando se usan políticas LSTM
        action, states = model.predict(obs, deterministic=False)
        #
        px = env.get_posicion(env.target)[0]
        py = env.get_posicion(env.target)[1]
        vx.append(np.array(px))
        vy.append(np.array(py))
        # here, action, rewards and dones are arrays
        # because we are using vectorized env
        obs, reward, done, tru, info = env.step(action)
        episode_rewards.append(reward)
        val += [reward]
        X_.append(env.step_counter)
        Y_.append(np.array(val).mean())
        
    all_episode_rewards.append(sum(episode_rewards))
plt.figure(figsize=(4,2), dpi=500)
plt.plot(X_, Y_)
plt.grid()
plt.title('Acumulated reward', fontsize=8)
plt.xlabel('Steps', fontsize=7)
plt.ylabel('Reward', fontsize=7)
plt.tick_params(axis='both', which='major', labelsize=7)
plt.show()

env.grafica(vx, vy)
mean_episode_reward = np.mean(all_episode_rewards)
print("Mean reward:", mean_episode_reward, "Num episodes:", num_episodes)
env.close()
# Out:
# Conectado al servidor API remoto
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# --------------------------------------------------------------------
# STEP:  1
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -1.524, Efector Final: -0.000
# RT: 0.657, RC: 0.248, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.655 ---
# --------------------------------------------------------------------
# STEP:  2
# Acciones:  [-0.101713 -1.       -1.      ]
# Angulos: Trayectoria Detectada: -0.778, Efector Final: 1.000
# RT: 0.835, RC: 0.250, RG: -2.000, RA: 0.525, RF: 0.000
# --- RECOMPENSA TOTAL: -0.390 ---
# --------------------------------------------------------------------
# STEP:  3
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -5.396, Efector Final: -0.000
# RT: 0.677, RC: 0.243, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.670 ---
# --------------------------------------------------------------------
# STEP:  4
# Acciones:  [ 0.9650864 -1.        -1.       ]
# Angulos: Trayectoria Detectada: -12.362, Efector Final: 1.000
# RT: 0.763, RC: 0.234, RG: -2.000, RA: 0.259, RF: 0.000
# --- RECOMPENSA TOTAL: -0.744 ---
# --------------------------------------------------------------------
# STEP:  5
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -19.212, Efector Final: -0.000
# RT: 0.861, RC: 0.223, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.834 ---
# --------------------------------------------------------------------
# STEP:  6
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -27.714, Efector Final: 1.000
# RT: 0.600, RC: 0.213, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.563 ---
# --------------------------------------------------------------------
# STEP:  7
# Acciones:  [ 0.17548554 -1.         -1.        ]
# Angulos: Trayectoria Detectada: -30.201, Efector Final: 2.000
# RT: 0.887, RC: 0.211, RG: -2.000, RA: 0.456, RF: 0.000
# --- RECOMPENSA TOTAL: -0.446 ---
# --------------------------------------------------------------------
# STEP:  8
# Acciones:  [0.7527402 1.        1.       ]
# Angulos: Trayectoria Detectada: -37.239, Efector Final: 1.000
# RT: 0.811, RC: 0.200, RG: 2.000, RA: 0.688, RF: 0.000
# --- RECOMPENSA TOTAL: 3.698 ---
# --------------------------------------------------------------------
# STEP:  9
# Acciones:  [0.48302948 1.         1.        ]
# Angulos: Trayectoria Detectada: -42.273, Efector Final: 2.000
# RT: 0.566, RC: 0.194, RG: 2.000, RA: 0.621, RF: 0.000
# --- RECOMPENSA TOTAL: 3.380 ---
# --------------------------------------------------------------------
# STEP:  10
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria Detectada: -53.395, Efector Final: 3.000
# RT: 0.583, RC: 0.180, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -0.987 ---
# --------------------------------------------------------------------
# STEP:  11
# Acciones:  [0.30486524 1.         1.        ]
# Angulos: Trayectoria Detectada: -54.712, Efector Final: 2.000
# RT: 0.861, RC: 0.177, RG: 2.000, RA: 0.576, RF: 0.000
# --- RECOMPENSA TOTAL: 3.614 ---
# --------------------------------------------------------------------
# STEP:  12
# Acciones:  [0.8389554 1.        1.       ]
# Angulos: Trayectoria Detectada: -55.498, Efector Final: 3.000
# RT: 0.887, RC: 0.177, RG: 2.000, RA: 0.710, RF: 0.000
# --- RECOMPENSA TOTAL: 3.774 ---
# --------------------------------------------------------------------
# STEP:  13
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -47.776, Efector Final: 4.000
# RT: 0.835, RC: 0.189, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.774 ---
# --------------------------------------------------------------------
# STEP:  14
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -34.841, Efector Final: 5.000
# RT: 0.914, RC: 0.209, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.872 ---
# --------------------------------------------------------------------
# STEP:  15
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -22.555, Efector Final: 6.000
# RT: 0.861, RC: 0.227, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.838 ---
# --------------------------------------------------------------------
# STEP:  16
# Acciones:  [-0.99124753  1.          1.        ]
# Angulos: Trayectoria Detectada: -29.681, Efector Final: 7.000
# RT: 0.361, RC: 0.218, RG: 2.000, RA: 0.252, RF: 0.000
# --- RECOMPENSA TOTAL: 2.831 ---
# --------------------------------------------------------------------
# STEP:  17
# Acciones:  [-0.815294 -1.       -1.      ]
# Angulos: Trayectoria Detectada: -40.825, Efector Final: 8.000
# RT: 0.445, RC: 0.204, RG: -2.000, RA: 0.704, RF: 0.000
# --- RECOMPENSA TOTAL: -0.647 ---
# --------------------------------------------------------------------
# STEP:  18
# Acciones:  [ 0.22500318 -1.         -1.        ]
# Angulos: Trayectoria Detectada: -41.090, Efector Final: 7.000
# RT: 0.861, RC: 0.203, RG: -2.000, RA: 0.444, RF: 0.000
# --- RECOMPENSA TOTAL: -0.493 ---
# --------------------------------------------------------------------
# STEP:  19
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -28.149, Efector Final: 6.000
# RT: 0.719, RC: 0.219, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.688 ---
# --------------------------------------------------------------------
# STEP:  20
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -16.541, Efector Final: 7.000
# RT: 0.549, RC: 0.237, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.536 ---
# --------------------------------------------------------------------
# STEP:  21
# Acciones:  [ 0.6727154 -1.        -1.       ]
# Angulos: Trayectoria Detectada: -13.246, Efector Final: 8.000
# RT: 0.887, RC: 0.243, RG: -2.000, RA: 0.332, RF: 0.000
# --- RECOMPENSA TOTAL: -0.539 ---
# --------------------------------------------------------------------
# STEP:  22
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -4.804, Efector Final: 7.000
# RT: 0.719, RC: 0.247, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.716 ---
# --------------------------------------------------------------------
# STEP:  23
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 5.222, Efector Final: 8.000
# RT: 0.432, RC: 0.232, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.587 ---
# --------------------------------------------------------------------
# STEP:  24
# Acciones:  [-1. -1. -1.]
# Angulos: Trayectoria Detectada: -4.804, Efector Final: 9.000
# RT: 0.719, RC: 0.244, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.287 ---
# --------------------------------------------------------------------
# STEP:  25
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 5.196, Efector Final: 8.000
# RT: 0.432, RC: 0.232, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.587 ---
# --------------------------------------------------------------------
# STEP:  26
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria Detectada: 7.565, Efector Final: 9.000
# RT: 0.811, RC: 0.227, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 3.288 ---
# --------------------------------------------------------------------
# STEP:  27
# Acciones:  [0.1139977 1.        1.       ]
# Angulos: Trayectoria Detectada: 10.244, Efector Final: 8.000
# RT: 0.445, RC: 0.225, RG: -2.000, RA: 0.528, RF: 0.000
# --- RECOMPENSA TOTAL: -0.802 ---
# --------------------------------------------------------------------
# STEP:  28
# Acciones:  [-0.41803175 -1.         -1.        ]
# Angulos: Trayectoria Detectada: 5.942, Efector Final: 9.000
# RT: 0.811, RC: 0.229, RG: 2.000, RA: 0.605, RF: 0.000
# --- RECOMPENSA TOTAL: 3.644 ---
# --------------------------------------------------------------------
# STEP:  29
# Acciones:  [0.307743 1.       1.      ]
# Angulos: Trayectoria Detectada: 9.734, Efector Final: 8.000
# RT: 0.445, RC: 0.225, RG: -2.000, RA: 0.577, RF: 0.000
# --- RECOMPENSA TOTAL: -0.753 ---
# --------------------------------------------------------------------
# STEP:  30
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria Detectada: 12.948, Efector Final: 9.000
# RT: 0.811, RC: 0.220, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 3.280 ---
# --------------------------------------------------------------------
# STEP:  31
# Acciones:  [0.47143644 1.         1.        ]
# Angulos: Trayectoria Detectada: 18.624, Efector Final: 8.000
# RT: 0.419, RC: 0.213, RG: -2.000, RA: 0.618, RF: 0.000
# --- RECOMPENSA TOTAL: -0.750 ---
# --------------------------------------------------------------------
# STEP:  32
# Acciones:  [ 0.07574722 -1.         -1.        ]
# Angulos: Trayectoria Detectada: 16.699, Efector Final: 9.000
# RT: 0.787, RC: 0.214, RG: 2.000, RA: 0.481, RF: 0.000
# --- RECOMPENSA TOTAL: 3.482 ---
# --------------------------------------------------------------------
# STEP:  33
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 26.611, Efector Final: 8.000
# RT: 0.372, RC: 0.202, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.676 ---
# --------------------------------------------------------------------
# STEP:  34
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria Detectada: 33.131, Efector Final: 9.000
# RT: 0.566, RC: 0.191, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 3.007 ---
# --------------------------------------------------------------------
# STEP:  35
# Acciones:  [ 0.5218777 -1.        -1.       ]
# Angulos: Trayectoria Detectada: 35.966, Efector Final: 8.000
# RT: 0.970, RC: 0.189, RG: 2.000, RA: 0.370, RF: 0.000
# --- RECOMPENSA TOTAL: 3.529 ---
# --------------------------------------------------------------------
# STEP:  36
# Acciones:  [0.2898842 1.        1.       ]
# Angulos: Trayectoria Detectada: 42.087, Efector Final: 7.000
# RT: 0.445, RC: 0.182, RG: -2.000, RA: 0.572, RF: 0.000
# --- RECOMPENSA TOTAL: -0.801 ---
# --------------------------------------------------------------------
# STEP:  37
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria Detectada: 50.988, Efector Final: 8.000
# RT: 0.583, RC: 0.168, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 3.001 ---
# --------------------------------------------------------------------
# STEP:  38
# Acciones:  [-0.8522349 -1.        -1.       ]
# Angulos: Trayectoria Detectada: 38.174, Efector Final: 7.000
# RT: 0.619, RC: 0.187, RG: 2.000, RA: 0.713, RF: 0.000
# --- RECOMPENSA TOTAL: 3.519 ---
# --------------------------------------------------------------------
# STEP:  39
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 52.795, Efector Final: 6.000
# RT: 0.533, RC: 0.168, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.549 ---
# --------------------------------------------------------------------
# STEP:  40
# Acciones:  [-0.4780116 -1.        -1.       ]
# Angulos: Trayectoria Detectada: 44.255, Efector Final: 7.000
# RT: 0.763, RC: 0.179, RG: 2.000, RA: 0.620, RF: 0.000
# --- RECOMPENSA TOTAL: 3.562 ---
# --------------------------------------------------------------------
# STEP:  41
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 58.297, Efector Final: 6.000
# RT: 0.395, RC: 0.161, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.695 ---
# --------------------------------------------------------------------
# STEP:  42
# Acciones:  [ 0.98535436 -1.         -1.        ]
# Angulos: Trayectoria Detectada: 64.635, Efector Final: 7.000
# RT: 0.407, RC: 0.151, RG: 2.000, RA: 0.254, RF: 0.000
# --- RECOMPENSA TOTAL: 2.811 ---
# --------------------------------------------------------------------
# STEP:  43
# Acciones:  [ 0.8306125 -1.        -1.       ]
# Angulos: Trayectoria Detectada: 67.341, Efector Final: 6.000
# RT: 0.419, RC: 0.148, RG: 2.000, RA: 0.292, RF: 0.000
# --- RECOMPENSA TOTAL: 2.859 ---
# --------------------------------------------------------------------
# STEP:  44
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria Detectada: 67.240, Efector Final: 5.000
# RT: 0.361, RC: 0.150, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 2.760 ---
# --------------------------------------------------------------------
# STEP:  45
# Acciones:  [-1. -1. -1.]
# Angulos: Trayectoria Detectada: 65.734, Efector Final: 4.000
# RT: 0.657, RC: 0.153, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.560 ---
# --------------------------------------------------------------------
# STEP:  46
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 67.240, Efector Final: 3.000
# RT: 0.361, RC: 0.152, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.737 ---
# --------------------------------------------------------------------
# STEP:  47
# Acciones:  [ 0.23808566 -1.         -1.        ]
# Angulos: Trayectoria Detectada: 67.229, Efector Final: 4.000
# RT: 0.502, RC: 0.151, RG: 2.000, RA: 0.440, RF: 0.000
# --- RECOMPENSA TOTAL: 3.093 ---
# --------------------------------------------------------------------
# STEP:  48
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria Detectada: 66.064, Efector Final: 3.000
# RT: 0.395, RC: 0.154, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 2.799 ---
# --------------------------------------------------------------------
# STEP:  49
# Acciones:  [-1. -1. -1.]
# Angulos: Trayectoria Detectada: 65.528, Efector Final: 2.000
# RT: 0.566, RC: 0.156, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.472 ---
# --------------------------------------------------------------------
# STEP:  50
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 66.064, Efector Final: 1.000
# RT: 0.395, RC: 0.157, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.699 ---
# --------------------------------------------------------------------
# STEP:  51
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria Detectada: 64.107, Efector Final: 2.000
# RT: 0.320, RC: 0.158, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 2.728 ---
# --------------------------------------------------------------------
# STEP:  52
# Acciones:  [-1. -1. -1.]
# Angulos: Trayectoria Detectada: 64.633, Efector Final: 1.000
# RT: 0.763, RC: 0.159, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.672 ---
# --------------------------------------------------------------------
# STEP:  53
# Acciones:  [0.41574657 1.         1.        ]
# Angulos: Trayectoria Detectada: 65.551, Efector Final: -0.000
# RT: 0.487, RC: 0.159, RG: -2.000, RA: 0.604, RF: 0.000
# --- RECOMPENSA TOTAL: -0.750 ---
# --------------------------------------------------------------------
# STEP:  54
# Acciones:  [ 0.56350625 -1.         -1.        ]
# Angulos: Trayectoria Detectada: 64.640, Efector Final: 1.000
# RT: 0.549, RC: 0.159, RG: 2.000, RA: 0.359, RF: 0.000
# --- RECOMPENSA TOTAL: 3.067 ---
# --------------------------------------------------------------------
# STEP:  55
# Acciones:  [-0.72360927 -1.         -1.        ]
# Angulos: Trayectoria Detectada: 63.730, Efector Final: -0.000
# RT: 0.533, RC: 0.161, RG: 2.000, RA: 0.681, RF: 0.000
# --- RECOMPENSA TOTAL: 3.375 ---
# --------------------------------------------------------------------
# STEP:  56
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 64.486, Efector Final: -1.000
# RT: 0.432, RC: 0.162, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.656 ---
# --------------------------------------------------------------------
# STEP:  57
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria Detectada: 62.823, Efector Final: -0.000
# RT: 0.350, RC: 0.163, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 2.763 ---
# --------------------------------------------------------------------
# STEP:  58
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria Detectada: 57.844, Efector Final: -1.000
# RT: 0.301, RC: 0.171, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 2.722 ---
# --------------------------------------------------------------------
# STEP:  59
# Acciones:  [-0.45225126 -1.         -1.        ]
# Angulos: Trayectoria Detectada: 59.491, Efector Final: -2.000
# RT: 0.741, RC: 0.170, RG: 2.000, RA: 0.613, RF: 0.000
# --- RECOMPENSA TOTAL: 3.524 ---
# --------------------------------------------------------------------
# STEP:  60
# Acciones:  [-0.34708405 -0.77143127 -0.84284663]
# Angulos: Trayectoria Detectada: 59.798, Efector Final: -3.000
# RT: 0.677, RC: 0.171, RG: 1.686, RA: 0.490, RF: 0.000
# --- RECOMPENSA TOTAL: 3.024 ---
# --------------------------------------------------------------------
# STEP:  61
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 55.829, Efector Final: -3.843
# RT: 0.407, RC: 0.178, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.666 ---
# --------------------------------------------------------------------
# STEP:  62
# Acciones:  [-0.42432252 -1.         -1.        ]
# Angulos: Trayectoria Detectada: 57.368, Efector Final: -2.843
# RT: 0.970, RC: 0.174, RG: 2.000, RA: 0.606, RF: 0.000
# --- RECOMPENSA TOTAL: 3.751 ---
# --------------------------------------------------------------------
# STEP:  63
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 50.367, Efector Final: -3.843
# RT: 0.284, RC: 0.185, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.781 ---
# --------------------------------------------------------------------
# STEP:  64
# Acciones:  [ 0.19001085 -1.         -1.        ]
# Angulos: Trayectoria Detectada: 46.989, Efector Final: -2.843
# RT: 0.458, RC: 0.189, RG: 2.000, RA: 0.452, RF: 0.000
# --- RECOMPENSA TOTAL: 3.100 ---
# --------------------------------------------------------------------
# STEP:  65
# Acciones:  [-0.37891114 -1.         -1.        ]
# Angulos: Trayectoria Detectada: 49.028, Efector Final: -3.843
# RT: 1.000, RC: 0.187, RG: 2.000, RA: 0.595, RF: 0.000
# --- RECOMPENSA TOTAL: 3.782 ---
# --------------------------------------------------------------------
# STEP:  66
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 40.027, Efector Final: -4.843
# RT: 0.340, RC: 0.201, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.709 ---
# --------------------------------------------------------------------
# STEP:  67
# Acciones:  [-0.53419137 -1.         -1.        ]
# Angulos: Trayectoria Detectada: 44.293, Efector Final: -3.843
# RT: 0.787, RC: 0.194, RG: 2.000, RA: 0.634, RF: 0.000
# --- RECOMPENSA TOTAL: 3.614 ---
# --------------------------------------------------------------------
# STEP:  68
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 35.353, Efector Final: -4.843
# RT: 0.284, RC: 0.208, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.759 ---
# --------------------------------------------------------------------
# STEP:  69
# Acciones:  [-0.28367397 -1.         -1.        ]
# Angulos: Trayectoria Detectada: 36.622, Efector Final: -3.843
# RT: 0.566, RC: 0.204, RG: 2.000, RA: 0.571, RF: 0.000
# --- RECOMPENSA TOTAL: 3.341 ---
# --------------------------------------------------------------------
# STEP:  70
# Acciones:  [-1. -1. -1.]
# Angulos: Trayectoria Detectada: 45.129, Efector Final: -4.843
# RT: 0.619, RC: 0.194, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.563 ---
# --------------------------------------------------------------------
# STEP:  71
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 36.622, Efector Final: -5.843
# RT: 0.566, RC: 0.207, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.477 ---
# --------------------------------------------------------------------
# STEP:  72
# Acciones:  [ 0.81673133 -1.         -1.        ]
# Angulos: Trayectoria Detectada: 25.976, Efector Final: -4.843
# RT: 0.763, RC: 0.221, RG: 2.000, RA: 0.296, RF: 0.000
# --- RECOMPENSA TOTAL: 3.280 ---
# --------------------------------------------------------------------
# STEP:  73
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 18.461, Efector Final: -5.843
# RT: 0.320, RC: 0.232, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.698 ---
# --------------------------------------------------------------------
# STEP:  74
# Acciones:  [ 0.21595886 -1.         -1.        ]
# Angulos: Trayectoria Detectada: 15.104, Efector Final: -4.843
# RT: 0.566, RC: 0.236, RG: 2.000, RA: 0.446, RF: 0.000
# --- RECOMPENSA TOTAL: 3.247 ---
# --------------------------------------------------------------------
# STEP:  75
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria Detectada: 6.334, Efector Final: -5.843
# RT: 0.887, RC: 0.249, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 3.386 ---
# --------------------------------------------------------------------
# STEP:  76
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 0.553, Efector Final: -6.843
# RT: 0.445, RC: 0.241, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.564 ---
# --------------------------------------------------------------------
# STEP:  77
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria Detectada: -5.963, Efector Final: -5.843
# RT: 0.787, RC: 0.234, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -0.730 ---
# --------------------------------------------------------------------
# STEP:  78
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -10.665, Efector Final: -6.843
# RT: 0.419, RC: 0.226, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.395 ---
# --------------------------------------------------------------------
# STEP:  79
# Acciones:  [ 0.53205585 -1.         -1.        ]
# Angulos: Trayectoria Detectada: -15.463, Efector Final: -5.843
# RT: 0.811, RC: 0.220, RG: -2.000, RA: 0.367, RF: 0.000
# --- RECOMPENSA TOTAL: -0.602 ---
# --------------------------------------------------------------------
# STEP:  80
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -20.961, Efector Final: -6.843
# RT: 0.487, RC: 0.211, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.448 ---
# --------------------------------------------------------------------
# STEP:  81
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria Detectada: -32.135, Efector Final: -5.843
# RT: 0.914, RC: 0.197, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -0.639 ---
# --------------------------------------------------------------------
# STEP:  82
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -40.551, Efector Final: -6.843
# RT: 0.763, RC: 0.184, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.698 ---
# --------------------------------------------------------------------
# STEP:  83
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -50.227, Efector Final: -5.843
# RT: 0.600, RC: 0.172, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.523 ---
# --------------------------------------------------------------------
# STEP:  84
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -59.444, Efector Final: -4.843
# RT: 0.566, RC: 0.161, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.476 ---
# --------------------------------------------------------------------
# STEP:  85
# Acciones:  [0.81440306 0.2589019  1.        ]
# Angulos: Trayectoria Detectada: -63.206, Efector Final: -3.843
# RT: 0.811, RC: 0.157, RG: 2.000, RA: 0.518, RF: 0.000
# --- RECOMPENSA TOTAL: 3.486 ---
# --------------------------------------------------------------------
# STEP:  86
# Acciones:  [0.34451652 1.         1.        ]
# Angulos: Trayectoria Detectada: -62.730, Efector Final: -2.843
# RT: 0.549, RC: 0.159, RG: 2.000, RA: 0.586, RF: 0.000
# --- RECOMPENSA TOTAL: 3.294 ---
# --------------------------------------------------------------------
# STEP:  87
# Acciones:  [1.        1.        0.9850137]
# Angulos: Trayectoria Detectada: -57.477, Efector Final: -1.843
# RT: 0.583, RC: 0.168, RG: 1.970, RA: 0.746, RF: 0.000
# --- RECOMPENSA TOTAL: 3.467 ---
# --------------------------------------------------------------------
# STEP:  88
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -45.524, Efector Final: -0.858
# RT: 0.549, RC: 0.186, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.484 ---
# --------------------------------------------------------------------
# STEP:  89
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria Detectada: -35.612, Efector Final: 0.142
# RT: 0.657, RC: 0.201, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -0.892 ---
# --------------------------------------------------------------------
# STEP:  90
# Acciones:  [0.20319152 1.         1.        ]
# Angulos: Trayectoria Detectada: -32.292, Efector Final: -0.858
# RT: 0.887, RC: 0.204, RG: 2.000, RA: 0.551, RF: 0.000
# --- RECOMPENSA TOTAL: 3.642 ---
# --------------------------------------------------------------------
# STEP:  91
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -20.955, Efector Final: 0.142
# RT: 0.600, RC: 0.221, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.572 ---
# --------------------------------------------------------------------
# STEP:  92
# Acciones:  [ 0.7664246 -1.        -1.       ]
# Angulos: Trayectoria Detectada: -15.838, Efector Final: 1.142
# RT: 0.763, RC: 0.230, RG: -2.000, RA: 0.308, RF: 0.000
# --- RECOMPENSA TOTAL: -0.699 ---
# --------------------------------------------------------------------
# STEP:  93
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -7.231, Efector Final: 0.142
# RT: 0.787, RC: 0.240, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 3.777 ---
# --------------------------------------------------------------------
# STEP:  94
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 0.000, Efector Final: 1.142
# RT: 0.432, RC: 0.248, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.570 ---
# --------------------------------------------------------------------
# STEP:  95
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria Detectada: 1.647, Efector Final: 2.142
# RT: 0.835, RC: 0.245, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 3.330 ---
# --------------------------------------------------------------------
# STEP:  96
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 2.176, Efector Final: 1.142
# RT: 0.445, RC: 0.245, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.560 ---
# --------------------------------------------------------------------
# STEP:  97
# Acciones:  [-0.46430567 -1.         -1.        ]
# Angulos: Trayectoria Detectada: 2.201, Efector Final: 2.142
# RT: 0.835, RC: 0.244, RG: 2.000, RA: 0.616, RF: 0.000
# --- RECOMPENSA TOTAL: 3.695 ---
# --------------------------------------------------------------------
# STEP:  98
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 1.776, Efector Final: 1.142
# RT: 0.445, RC: 0.246, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.559 ---
# --------------------------------------------------------------------
# STEP:  99
# Acciones:  [ 0.42837617 -1.         -1.        ]
# Angulos: Trayectoria Detectada: 2.493, Efector Final: 2.142
# RT: 0.835, RC: 0.244, RG: 2.000, RA: 0.393, RF: 0.000
# --- RECOMPENSA TOTAL: 3.472 ---
# --------------------------------------------------------------------
# STEP:  100
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: 2.203, Efector Final: 1.142
# RT: 0.445, RC: 0.245, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -0.560 ---
# --------------------------------------------------------------------
# STEP:  101
# Acciones:  [ 0.8734899 -1.        -1.       ]
# Angulos: Trayectoria Detectada: 0.417, Efector Final: 2.142
# RT: 0.835, RC: 0.246, RG: 2.000, RA: 0.282, RF: 10.000
# --- RECOMPENSA TOTAL: 13.363 ---
# --------------------------------------------------------------------
# STEP:  102
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria Detectada: -87.275, Efector Final: 1.142
# RT: 0.458, RC: 0.130, RG: 2.000, RA: 0.750, RF: 10.000
# --- RECOMPENSA TOTAL: 13.339 ---
#  --- REINICIO ---
# Mean reward: 217.46993581288615 Num episodes: 1

# %%
model = A2C.load("best_model", env=env)
print(model.policy)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ActorCriticCnnPolicy(
#   (features_extractor): CustomCNN(
#     (cnn): Sequential(
#       (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU()
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU()
#       (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (9): Flatten(start_dim=1, end_dim=-1)
#       (10): Linear(in_features=3456, out_features=32, bias=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=3, bias=True)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=3, out_features=3, bias=True)
#     )
#   )
#   (pi_features_extractor): CustomCNN(
#     (cnn): Sequential(
#       (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU()
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU()
#       (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (9): Flatten(start_dim=1, end_dim=-1)
#       (10): Linear(in_features=3456, out_features=32, bias=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=3, bias=True)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=3, out_features=3, bias=True)
#     )
#   )
#   (vf_features_extractor): CustomCNN(
#     (cnn): Sequential(
#       (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU()
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU()
#       (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (9): Flatten(start_dim=1, end_dim=-1)
#       (10): Linear(in_features=3456, out_features=32, bias=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=3, bias=True)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=3, out_features=3, bias=True)
#     )
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=3, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=3, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=3, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )
